# %% [markdown]
# # REGRESIÓN LINEAL

# %%
import numpy as np
from sklearn.datasets import make_regression
import  matplotlib.pyplot as plt

# %%
X, y = make_regression(n_samples=100, n_features=1, noise=5)

# %%
figura = plt.figure(dpi=150)
plt.scatter(X, y, marker='+')
plt.grid()

# %% [markdown]
# # LinearRegression (SKLEARN) - Mínimos Cuadrados

# %%
from sklearn.linear_model import LinearRegression

# %%
regresion_sklearn = LinearRegression()

# %%
regresion_sklearn.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regresion_sklearn.coef_, regresion_sklearn.intercept_, regresion_sklearn.score(X,y)
# Out:
# (array([22.54365076]), -0.6177870439125339, 0.9534184097249571)

# %% [markdown]
# # linregress (SCIPY) - Mínimos Cuadrados

# %%
from scipy.stats import linregress

# %%
X.shape, y.shape
# Out:
# ((100, 1), (100,))

# %%
a, b, r, p, stderr = linregress(X.reshape(-1,), y)

# %%
print(linregress(X.reshape(-1,), y))
# Out:
# LinregressResult(slope=22.5436507554855, intercept=-0.6177870439125366, rvalue=0.9764314669883172, pvalue=4.548484215807344e-67, stderr=0.5033575634226212)

# %%
r **2
# Out:
# 0.9534184097249572

# %% [markdown]
# # DESCENSO DEL GRADIENTE ESTOCÁSTICO

# %%
from sklearn.linear_model import SGDRegressor

# %%
regr = SGDRegressor(max_iter=5000, tol=1e-5, random_state=20)

# %%
regr.fit(X, y)
# Out:
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#              eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='invscaling', loss='squared_loss', max_iter=5000,
#              n_iter_no_change=5, penalty='l2', power_t=0.25, random_state=20,
#              shuffle=True, tol=1e-05, validation_fraction=0.1, verbose=0,
#              warm_start=False)

# %%
regr.coef_, regr.intercept_, regr.score(X,y)
# Out:
# (array([22.53555412]), array([-0.6184736]), 0.953418276871463)

# %%
plt.figure(dpi=150)
plt.scatter(X,y, marker='+')
plt.plot(X, regresion_sklearn.coef_*X+regresion_sklearn.intercept_, color='green', lw=0.1)
plt.plot(X, regr.coef_*X + regr.intercept_, color = 'red', lw=0.1)
plt.grid()

# %% [markdown]
# # SIGNIFICADO ESTOCÁSTICO:
#
#     - Se define una época como una pasada por todas las muestras de un experimento
#
#     - Se van sirviendo las muestras previa permutación de su orden antes de cada época
#
#     - Se corrobora experimentalmente que es más eficiente

# %%
from random import shuffle
epoca = ['a', 'b', 'c', 'd', 'e']

# %%
for i in range(5):
    shuffle(epoca)
    print(epoca)
# Out:
# ['d', 'b', 'c', 'e', 'a']
# ['b', 'e', 'c', 'd', 'a']
# ['d', 'a', 'b', 'c', 'e']
# ['b', 'c', 'e', 'a', 'd']
# ['d', 'c', 'a', 'b', 'e']
